# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
np.random.seed(42)

X = np.random.rand(50, 1) * 100
Y = 3.5 * X + np.random.randn(50, 1) * 20

data = pd.read_csv('students_weight_height.csv')
print(data.head())
# Out:
#    height_cm  weight_kg
# 0     153.22      38.23
# 1     150.51      38.87
# 2     154.65      41.75
# 3     151.77      39.35
# 4     164.74      47.87

# %%
X = data['weight_kg']
X
# Out:
# 0     38.23
# 1     38.87
# 2     41.75
# 3     39.35
# 4     47.87
# 5     42.22
# 6     42.67
# 7     43.37
# 8     45.31
# 9     43.42
# 10    45.90
# 11    41.54
# 12    43.82
# 13    46.43
# 14    46.93
# 15    47.29
# 16    47.26
# 17    47.93
# 18    49.66
# 19    47.55
# 20    49.82
# 21    51.35
# 22    50.91
# 23    52.52
# 24    54.20
# 25    52.20
# 26    52.39
# 27    53.28
# 28    55.91
# 29    54.30
# 30    49.88
# 31    55.71
# 32    56.63
# 33    57.06
# 34    55.47
# 35    59.59
# 36    48.88
# 37    57.19
# 38    58.06
# 39    37.77
# 40    41.35
# 41    39.54
# 42    41.88
# 43    43.36
# 44    45.23
# 45    47.28
# 46    46.86
# 47    47.02
# 48    48.95
# 49    50.38
# 50    52.11
# 51    48.39
# 52    52.66
# 53    55.04
# 54    55.02
# 55    55.96
# 56    57.76
# 57    58.75
# Name: weight_kg, dtype: float64

# %%
plt.scatter(data['weight_kg'], data['height_cm'])
plt.title('Weight vs Height')
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
# Out:
# Text(0, 0.5, 'Height (cm)')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data[['weight_kg']], data['height_cm'], test_size=0.2, random_state=42)

# %%
X_test
# Out:
#     weight_kg
# 0       38.23
# 5       42.22
# 34      55.47
# 13      46.43
# 44      45.23
# 52      52.66
# 37      57.19
# 25      52.20
# 46      46.86
# 12      43.82
# 48      48.95
# 3       39.35

# %%
# Standarization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(8,6)) 
plt.scatter(X_test, Y_test, color='blue', label='Data Points') 
plt.plot(X_test, Y_pred, color='red', linewidth=2, label='Regression Line') 
plt.title('Linear Regression on Random Dataset')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficient: [1.86672392]
# Intercept: 78.16824802694717
