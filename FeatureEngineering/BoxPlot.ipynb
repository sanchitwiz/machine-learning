# %% [markdown]
# ### 5 Number Summary and Box Plot

# %%
## Minimum, Maximum, Median, Q1, Q3, IQR
import numpy as np

# %%
lst_marks = [75, 88, 92, 85, 79, 95, 89, 73, 84, 91, 87, 90, 78, 82, 94]
five_number_summary = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])
print(len(five_number_summary))
print(five_number_summary)
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks, [0, 0.25, 0.50, 0.75, 1.0])
# Out:
# 5
# [73.  80.5 87.  90.5 95. ]

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 10.0

# %%
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

# %%
lower_fence, upper_fence
print(lower_fence, upper_fence)
# Out:
# 65.5 105.5

# %%
lst_marks = [75, 88, 92, 85, 79, 95, 89, 73, 84, 91, 87, 90, 78, 82, 94]
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-10, 75, 88, 92, 85, 79, 95, 89, 73, 84, 91, 87, 90, 78, 82, 94, 150, 170]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
